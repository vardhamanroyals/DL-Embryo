# %%
# =========================
# FIX TRUNCATED IMAGES      #MobileNet New
# =========================
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# =========================
# IMPORTS
# =========================
import os
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import random

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models

# =========================
# SEED
# =========================
random.seed(42)
tf.random.set_seed(42)

# =========================
# PATHS
# =========================
IMG_ROOT = "/kaggle/input/datasets/abhishekbuddiga06/embryo-dataset/embryo_dataset/embryo_dataset"
ANN_ROOT = "/kaggle/input/datasets/abhishekbuddiga06/embryo-dataset/embryo_dataset_annotations/embryo_dataset_annotations"

# =========================
# VIDEO SPLIT
# =========================
folders = os.listdir(IMG_ROOT)
folders = [f for f in folders if os.path.isdir(os.path.join(IMG_ROOT, f))]

random.shuffle(folders)

split = int(0.8 * len(folders))
train_folders = folders[:split]
val_folders = folders[split:]

print("Train folders:", len(train_folders))
print("Val folders:", len(val_folders))

# =========================
# LOAD DATA
# =========================
def load_data(folders):
    data = []
    for folder in folders:
        img_folder = os.path.join(IMG_ROOT, folder)
        csv_file = os.path.join(ANN_ROOT, folder + "_phases.csv")

        if not os.path.exists(csv_file):
            continue

        df = pd.read_csv(csv_file, header=None, names=['phase','start','end'])
        images = sorted(os.listdir(img_folder))

        if len(images) == 0:
            continue

        total_images = len(images)
        max_frame = df['end'].max() + 1

        for _, row in df.iterrows():
            label = str(row['phase'])

            start_idx = int(row['start']/max_frame * total_images)
            end_idx   = int(row['end']/max_frame * total_images)

            for i in range(start_idx, min(end_idx+1, total_images)):
                data.append((os.path.join(img_folder, images[i]), label))

    return pd.DataFrame(data, columns=['path','label'])

train_df = load_data(train_folders)
val_df   = load_data(val_folders)

print("Train samples:", len(train_df))
print("Val samples:", len(val_df))

# ❗ IMPORTANT: DO NOT REMOVE IMAGES (for now)
# Commenting out remove_bad to avoid empty dataset

# =========================
# GENERATORS
# =========================
IMG_SIZE = (128,128)
BATCH_SIZE = 8

train_data = ImageDataGenerator(rescale=1./255).flow_from_dataframe(
    train_df,
    x_col='path',
    y_col='label',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

val_data = ImageDataGenerator(rescale=1./255).flow_from_dataframe(
    val_df,
    x_col='path',
    y_col='label',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print("Train batches:", len(train_data))
print("Val batches:", len(val_data))

# =========================
# MODEL
# =========================
base = MobileNetV2(weights='imagenet', include_top=False, input_shape=(128,128,3))
base.trainable = False

x = layers.GlobalAveragePooling2D()(base.output)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.4)(x)
output = layers.Dense(len(train_data.class_indices), activation='softmax')(x)

model = models.Model(inputs=base.input, outputs=output)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']   # simpler metric for debugging
)

model.summary()

# =========================
# TRAIN (FORCE RUN)
# =========================
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=5
)

# =========================
# PLOT
# =========================
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.title("Loss")
plt.show()
# Out:
# Train folders: 563
# Val folders: 141
# Train samples: 266193
# Val samples: 64800
# Found 266108 validated image filenames belonging to 16 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py:920: UserWarning: Found 85 invalid image filename(s) in x_col="path". These filename(s) will be ignored.
#   warnings.warn(
# Found 64769 validated image filenames belonging to 16 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py:920: UserWarning: Found 31 invalid image filename(s) in x_col="path". These filename(s) will be ignored.
#   warnings.warn(
# Train batches: 33264
# Val batches: 8097
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# ...

# %%
import matplotlib.pyplot as plt

# =========================
# Training history (from your output)
# =========================
epochs = [1, 2, 3, 4, 5]

train_accuracy = [0.2831, 0.3150, 0.3228, 0.3279, 0.3303]
val_accuracy   = [0.2975, 0.3111, 0.3086, 0.3114, 0.2990]

train_loss = [2.1550, 1.9884, 1.9545, 1.9356, 1.9230]
val_loss   = [2.1575, 2.1300, 2.1486, 2.2311, 2.1899]

# =========================
# Plot Accuracy
# =========================
plt.figure(figsize=(8,5))
plt.plot(epochs, train_accuracy, marker='o', label='Train Accuracy')
plt.plot(epochs, val_accuracy, marker='o', label='Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# =========================
# Plot Loss
# =========================
plt.figure(figsize=(8,5))
plt.plot(epochs, train_loss, marker='o', label='Train Loss')
plt.plot(epochs, val_loss, marker='o', label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()
