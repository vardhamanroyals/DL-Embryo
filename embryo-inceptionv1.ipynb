# %%
# =========================
# FIX TRUNCATED IMAGES       #Inception V1
# =========================
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# =========================
# IMPORTS
# =========================
import os
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import random

from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
import tensorflow.keras.backend as K

# =========================
# SEED
# =========================
random.seed(42)
tf.random.set_seed(42)

# =========================
# PATHS
# =========================
IMG_ROOT = "/kaggle/input/datasets/abhishekbuddiga06/embryo-dataset/embryo_dataset/embryo_dataset"
ANN_ROOT = "/kaggle/input/datasets/abhishekbuddiga06/embryo-dataset/embryo_dataset_annotations/embryo_dataset_annotations"

# =========================
# VIDEO SPLIT
# =========================
folders = [
    f for f in os.listdir(IMG_ROOT)
    if os.path.isdir(os.path.join(IMG_ROOT, f))
]

random.shuffle(folders)

split = int(0.8 * len(folders))
train_folders = folders[:split]
val_folders   = folders[split:]

print("Train Videos:", len(train_folders))
print("Val Videos:", len(val_folders))

# =========================
# LOAD DATA
# =========================
def load_data(folders):
    data = []

    for folder in folders:
        img_folder = os.path.join(IMG_ROOT, folder)
        csv_file = os.path.join(ANN_ROOT, folder + "_phases.csv")

        if not os.path.exists(img_folder) or not os.path.exists(csv_file):
            continue

        df = pd.read_csv(csv_file, header=None, names=['phase','start','end'])
        images = sorted(os.listdir(img_folder))

        if len(images) == 0:
            continue

        total_images = len(images)
        max_frame = df['end'].max() + 1

        for _, row in df.iterrows():
            label = str(row['phase'])

            start_idx = int(row['start'] / max_frame * total_images)
            end_idx   = int(row['end']   / max_frame * total_images)

            for i in range(start_idx, min(end_idx+1, total_images)):
                data.append((os.path.join(img_folder, images[i]), label))

    return pd.DataFrame(data, columns=['path','label'])

train_df = load_data(train_folders)
val_df   = load_data(val_folders)

print("Train Images:", len(train_df))
print("Val Images:", len(val_df))

# =========================
# SAFE CLEAN
# =========================
def safe_clean(df):
    valid = []
    for p in df['path'][:2000]:
        try:
            img = Image.open(p)
            img.verify()
            valid.append(p)
        except:
            continue
    return df[df['path'].isin(valid)]

train_df = safe_clean(train_df)
val_df   = safe_clean(val_df)

# =========================
# GENERATORS
# =========================
IMG_SIZE = (128,128)
BATCH_SIZE = 8

train_data = ImageDataGenerator(rescale=1./255).flow_from_dataframe(
    train_df,
    x_col='path',
    y_col='label',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

val_data = ImageDataGenerator(rescale=1./255).flow_from_dataframe(
    val_df,
    x_col='path',
    y_col='label',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print("Train batches:", len(train_data))
print("Val batches:", len(val_data))

NUM_CLASSES = len(train_data.class_indices)

# =========================
# METRICS
# =========================
def exact_accuracy(y_true, y_pred):
    return tf.reduce_mean(
        tf.cast(tf.equal(tf.argmax(y_true,1), tf.argmax(y_pred,1)), tf.float32)
    )

def tolerance_accuracy(y_true, y_pred):
    true = tf.argmax(y_true,1)
    pred = tf.argmax(y_pred,1)
    return tf.reduce_mean(
        tf.cast(tf.abs(true - pred) <= 1, tf.float32)
    )

# =========================
# INCEPTION BLOCK
# =========================
def inception_block(x, f1, f3r, f3, f5r, f5, proj):
    path1 = layers.Conv2D(f1, (1,1), padding='same', activation='relu')(x)

    path2 = layers.Conv2D(f3r, (1,1), padding='same', activation='relu')(x)
    path2 = layers.Conv2D(f3, (3,3), padding='same', activation='relu')(path2)

    path3 = layers.Conv2D(f5r, (1,1), padding='same', activation='relu')(x)
    path3 = layers.Conv2D(f5, (5,5), padding='same', activation='relu')(path3)

    path4 = layers.MaxPooling2D((3,3), strides=1, padding='same')(x)
    path4 = layers.Conv2D(proj, (1,1), padding='same', activation='relu')(path4)

    return layers.concatenate([path1, path2, path3, path4])

# =========================
# MODEL (GOOGLENET)
# =========================
inputs = layers.Input(shape=(128,128,3))

x = layers.Conv2D(64, (7,7), strides=2, padding='same', activation='relu')(inputs)
x = layers.MaxPooling2D((3,3), strides=2)(x)

x = layers.Conv2D(64, (1,1), activation='relu')(x)
x = layers.Conv2D(192, (3,3), padding='same', activation='relu')(x)
x = layers.MaxPooling2D((3,3), strides=2)(x)

x = inception_block(x, 64, 96, 128, 16, 32, 32)
x = inception_block(x, 128, 128, 192, 32, 96, 64)

x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.4)(x)

outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)

model = models.Model(inputs, outputs)

# =========================
# COMPILE
# =========================
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=[exact_accuracy, tolerance_accuracy]
)

model.summary()

# =========================
# TRAIN (FIXED)
# =========================
if len(train_data) == 0 or len(val_data) == 0:
    raise ValueError("❌ No data to train!")

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10
)

# =========================
# PLOTS
# =========================
plt.figure()
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.title("GoogLeNet Loss")
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['exact_accuracy'], label='Train Exact')
plt.plot(history.history['val_exact_accuracy'], label='Val Exact')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['tolerance_accuracy'], label='Train Tol')
plt.plot(history.history['val_tolerance_accuracy'], label='Val Tol')
plt.legend()
plt.show()

# =========================
# CLEAR MEMORY
# =========================
K.clear_session()
# Out:
# 2026-04-08 09:06:58.208123: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775639218.409079      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775639218.472769      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775639218.964871      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775639218.964935      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775639218.964938      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775639218.964939      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Train Videos: 563
# Val Videos: 141
# Train Images: 266193
# Val Images: 64800
# Found 2000 validated image filenames belonging to 15 classes.
# Found 2000 validated image filenames belonging to 15 classes.
# Train batches: 250
# Val batches: 250
# 2026-04-08 09:08:28.189405: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 64, 64,    │      9,472 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 31, 31,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 31, 31,    │      4,160 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 31, 31,    │    110,784 │ conv2d_1[0][0]    │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 15, 15,    │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 15, 15,    │     18,528 │ max_pooling2d_1[… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 15, 15,    │      3,088 │ max_pooling2d_1[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 15, 15,    │          0 │ max_pooling2d_1[… │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 15, 15,    │     12,352 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 15, 15,    │    110,720 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 15, 15,    │     12,832 │ conv2d_6[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 15, 15,    │      6,176 │ max_pooling2d_2[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 15, 15,    │          0 │ conv2d_3[0][0],   │
# │ (Concatenate)       │ 256)              │            │ conv2d_5[0][0],   │
# │                     │                   │            │ conv2d_7[0][0],   │
# │                     │                   │            │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 15, 15,    │     32,896 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 15, 15,    │      8,224 │ concatenate[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 15, 15,    │          0 │ concatenate[0][0] │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 15, 15,    │     32,896 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 15, 15,    │    221,376 │ conv2d_10[0][0]   │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 15, 15,    │     76,896 │ conv2d_12[0][0]   │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 15, 15,    │     16,448 │ max_pooling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 15, 15,    │          0 │ conv2d_9[0][0],   │
# │ (Concatenate)       │ 480)              │            │ conv2d_11[0][0],  │
# │                     │                   │            │ conv2d_13[0][0],  │
# │                     │                   │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 480)       │          0 │ concatenate_1[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 480)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 15)        │      7,215 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 684,063 (2.61 MB)
#  Trainable params: 684,063 (2.61 MB)
#  Non-trainable params: 0 (0.00 B)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 164ms/step - exact_accuracy: 0.1450 - loss: 2.5254 - tolerance_accuracy: 0.2130 - val_exact_accuracy: 0.1490 - val_loss: 2.6368 - val_tolerance_accuracy: 0.2290
# Epoch 2/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 162ms/step - exact_accuracy: 0.1687 - loss: 2.3830 - tolerance_accuracy: 0.2520 - val_exact_accuracy: 0.1490 - val_loss: 2.6488 - val_tolerance_accuracy: 0.2290
# Epoch 3/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - exact_accuracy: 0.1840 - loss: 2.3612 - tolerance_accuracy: 0.2763 - val_exact_accuracy: 0.0955 - val_loss: 2.9903 - val_tolerance_accuracy: 0.1915
# Epoch 4/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - exact_accuracy: 0.1718 - loss: 2.2957 - tolerance_accuracy: 0.2654 - val_exact_accuracy: 0.1490 - val_loss: 2.8778 - val_tolerance_accuracy: 0.2290
# Epoch 5/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 168ms/step - exact_accuracy: 0.1864 - loss: 2.2978 - tolerance_accuracy: 0.2648 - val_exact_accuracy: 0.1120 - val_loss: 2.8577 - val_tolerance_accuracy: 0.1955
# Epoch 6/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 163ms/step - exact_accuracy: 0.2013 - loss: 2.2591 - tolerance_accuracy: 0.2928 - val_exact_accuracy: 0.1555 - val_loss: 3.0023 - val_tolerance_accuracy: 0.2290
# Epoch 7/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - exact_accuracy: 0.2085 - loss: 2.2495 - tolerance_accuracy: 0.2871 - val_exact_accuracy: 0.1105 - val_loss: 2.9449 - val_tolerance_accuracy: 0.1395
# Epoch 8/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 162ms/step - exact_accuracy: 0.2485 - loss: 2.2111 - tolerance_accuracy: 0.3451 - val_exact_accuracy: 0.1185 - val_loss: 2.9289 - val_tolerance_accuracy: 0.2025
# Epoch 9/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - exact_accuracy: 0.2906 - loss: 2.1201 - tolerance_accuracy: 0.3754 - val_exact_accuracy: 0.2010 - val_loss: 2.9785 - val_tolerance_accuracy: 0.3025
# Epoch 10/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - exact_accuracy: 0.2986 - loss: 2.0918 - tolerance_accuracy: 0.4224 - val_exact_accuracy: 0.2195 - val_loss: 2.9909 - val_tolerance_accuracy: 0.3270
